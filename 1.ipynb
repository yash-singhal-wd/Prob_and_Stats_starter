# %%
# task1_iris_pdf_cdf.py

from sklearn.datasets import load_iris
import numpy as np
import pandas as pd

# Load the Iris dataset
iris = load_iris()

# Extract features and target
X = iris.data
y = iris.target
feature_names = iris.feature_names
target_names = iris.target_names

# Convert to a pandas DataFrame for convenience
df = pd.DataFrame(X, columns=feature_names)
df['target'] = y

# Display the first few rows
print("First 5 rows of the Iris dataset:")
print(df.head())

# Print feature names and target classes
print("Feature names:")
print(feature_names)

print("Target classes:")
print(target_names)
# Out:
# 🔍 First 5 rows of the Iris dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# Feature names:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target classes:
# ['setosa' 'versicolor' 'virginica']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

print(df.columns)

sns.kdeplot(data=df, x=df.columns[0], hue='target', common_norm=False)
plt.show()
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
sns.kdeplot(data=df, x=df.columns[1], hue='target', common_norm=False)
plt.show()

# %%
sns.kdeplot(data=df, x=df.columns[2], hue='target', common_norm=False)
plt.show()

# %%
sns.kdeplot(data=df, x=df.columns[3], hue='target', common_norm=False)
plt.show()

# %%
sns.kdeplot(
    data=df,
    x=df.columns[0],
    hue='target',
    cumulative=True,
    common_norm=False,
    palette={0: 'red', 1: 'green', 2: 'blue'}
)
plt.show()

# %%
sns.kdeplot(
    data=df,
    x=df.columns[1],
    hue='target',
    cumulative=True,
    common_norm=False,
    palette={0: 'red', 1: 'green', 2: 'blue'}
)
plt.show()

# %%
sns.kdeplot(
    data=df,
    x=df.columns[2],
    hue='target',
    cumulative=True,
    common_norm=False,
    palette={0: 'red', 1: 'green', 2: 'blue'}
)
plt.show()

# %%
sns.kdeplot(
    data=df,
    x=df.columns[3],
    hue='target',
    cumulative=True,
    common_norm=False,
    palette={0: 'red', 1: 'green', 2: 'blue'}
)
plt.show()
